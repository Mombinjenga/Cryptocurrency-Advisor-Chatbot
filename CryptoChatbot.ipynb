# %% [markdown]
# <a href="https://colab.research.google.com/github/Mombinjenga/Cryptocurrency-Advisor-Chatbot/blob/main/CryptoChatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Part 1 — imports, load dataset, quick sanity checks

# Libraries
import pandas as pd
import numpy as np

# Filename
FILE = "crypto_data.csv"

# Load and parse dates
df = pd.read_csv(FILE, parse_dates=["date"], infer_datetime_format=True)

# Sort by date and reset index
df = df.sort_values("date").reset_index(drop=True)

# Quick checks
print("rows, cols:", df.shape)
print("date range:", df['date'].min(), "to", df['date'].max())
print("missing per column:\n", df.isna().sum())

# Show first 5 rows
df.head()
# Out:
# /tmp/ipython-input-1675679773.py:11: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df = pd.read_csv(FILE, parse_dates=["date"], infer_datetime_format=True)
# rows, cols: (244908, 13)
# date range: 2013-04-28 00:00:00 to 2018-11-29 00:00:00
# missing per column:
#  slug           0
# symbol         0
# name           0
# date           0
# ranknow        0
# open           0
# high           0
# low            1
# close          1
# volume         1
# market         1
# close_ratio    1
# spread         1
# dtype: int64
#        slug symbol      name       date  ranknow        open        high  \
# 0   bitcoin    BTC   Bitcoin 2013-04-28        1  135.300000  135.980000
# 1  peercoin    PPC  Peercoin 2013-04-28      159    0.386958    0.404659
# ...

# %%
# Part 2 — clean dataset and create prediction targets

# Remove any rows with missing values
df = df.dropna()

# Create next-day closing price target
df['target_close'] = df['close'].shift(-1)

# Create direction target: 1 = up, 0 = down
df['target_direction'] = (df['target_close'] > df['close']).astype(int)

# Drop last row (because the target becomes NaN)
df = df[:-1]

# Quick check
df[['close', 'target_close', 'target_direction']].head()
# Out:
#         close  target_close  target_direction
# 0  134.210000      0.386525                 0
# 1    0.386525      1.110000                 1
# 2    1.110000      4.350000                 1
# 3    4.350000    144.540000                 1
# 4  144.540000      1.330000                 0
